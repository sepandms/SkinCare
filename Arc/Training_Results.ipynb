# %%
0.9e-3
# Out:
# 0.0009

# %%
import pandas as pd
import os
import pickle
import matplotlib.pyplot as plt
from CNN_NETs import CNN_Nets
import torch


G_path = '/Users/sepehrbe/My_Drive/DataSources/SkinCare'
G_saved = G_path+ '/Saved/'
G_Grid = G_path+ '/Saved/Grid_Search_Results'

files = list(os.listdir(G_Grid))
f = 'CNN_280x210_Model3_21_Jun22_15-01'
f = 'CNN_280x210_Model7_21_Jun22_13-37'
GridSrach = pickle.load(open(G_Grid + '/' + f , 'rb'))

# %%
GridSrach
# Out:
#                          model_name  \
#   CNN_280x210_Model0_21_Jun22_13-37
#   CNN_280x210_Model1_21_Jun22_13-37
#   CNN_280x210_Model2_21_Jun22_13-37
#   CNN_280x210_Model3_21_Jun22_13-37
#   CNN_280x210_Model4_21_Jun22_13-37
#   CNN_280x210_Model5_21_Jun22_13-37
#   CNN_280x210_Model6_21_Jun22_13-37
#   CNN_280x210_Model7_21_Jun22_13-37
#
#                                         hyper_param  test_overall_metric  \
#   {'Drop': 0.2, 'LR': 0.001, 'Momentum': 0.78, '...             0.623375
#   {'Drop': 0.2, 'LR': 0.001, 'Momentum': 0.78, '...             0.621348
#   {'Drop': 0.2, 'LR': 0.001, 'Momentum': 0.82, '...             0.617906
#   {'Drop': 0.2, 'LR': 0.001, 'Momentum': 0.82, '...             0.631586
#   {'Drop': 0.2, 'LR': 0.0011, 'Momentum': 0.78, ...             0.629689
#   {'Drop': 0.2, 'LR': 0.0011, 'Momentum': 0.78, ...             0.620444
#   {'Drop': 0.2, 'LR': 0.0011, 'Momentum': 0.82, ...             0.619594
#   {'Drop': 0.2, 'LR': 0.0011, 'Momentum': 0.82, ...             0.614822
#
#   test_recall  blc_test_recall  valid_recall  train_accuracy  valid_accuracy  \
#      0.619627         0.619048      0.598495        0.803125        0.658477
#      0.625223         0.600000      0.554778        0.846354        0.656020
#      0.607830         0.609524      0.566349        0.823177        0.668305
#      0.629214         0.609524      0.587784        0.877604        0.680590
#      0.621676         0.628571      0.597966        0.812760        0.660934
#      0.624663         0.590476      0.543438        0.862500        0.658477
#      0.600915         0.619048      0.592874        0.835677        0.678133
#      0.607799         0.590476      0.564851        0.890365        0.663391
#
#   test_accuracy                                   train_epoch_loss  \
#        0.631450  [1.9225987039506436, 1.8561821952462196, 1.775...
#        0.638821  [1.922210231423378, 1.852711769938469, 1.76769...
#        0.636364  [1.917621622234583, 1.8350770793855191, 1.7406...
#        0.656020  [1.9170230679214, 1.830355765670538, 1.7295292...
#        0.638821  [1.9202798560261727, 1.8463722050189972, 1.759...
#        0.646192  [1.919761785119772, 1.8420795127749443, 1.7500...
#        0.638821  [1.9148078337311745, 1.8235138945281506, 1.719...
#        0.646192  [1.9140308611094952, 1.8179173924028873, 1.707...
#
#                                     train_epoch_acc  \
#   [0.15677083333333333, 0.24817708333333333, 0.2...
#   [0.15703125, 0.253125, 0.30130208333333336, 0....
#   [0.16432291666666668, 0.26979166666666665, 0.3...
#   [0.16510416666666666, 0.26953125, 0.31484375, ...
#   [0.15989583333333332, 0.26328125, 0.3015625, 0...
#   [0.1609375, 0.2669270833333333, 0.30703125, 0....
#   [0.16744791666666667, 0.27447916666666666, 0.3...
#   [0.16979166666666667, 0.2796875, 0.3265625, 0....
#
#                                    valid_epoch_loss  \
#   [1.8349398234311272, 1.7623423548305737, 1.679...
#   [1.8328128982992733, 1.7596792403389425, 1.675...
#   [1.8180741282070385, 1.738072156906128, 1.6720...
#   [1.8159179617376888, 1.7322958637686336, 1.673...
#   [1.8264848344466265, 1.7529562080607695, 1.678...
#   [1.8241405416937435, 1.7485451768426334, 1.677...
#   [1.8095257001764633, 1.7279551730436438, 1.677...
#   [1.8065165772157556, 1.7218459844589233, 1.666...
#
#                                     valid_epoch_acc  \
#   [0.47058823529411764, 0.3480392156862745, 0.33...
#   [0.47549019607843135, 0.34558823529411764, 0.3...
#   [0.49019607843137253, 0.32598039215686275, 0.3...
#   [0.49754901960784315, 0.33333333333333337, 0.3...
#   [0.4803921568627451, 0.3284313725490196, 0.333...
#   [0.4803921568627451, 0.3284313725490196, 0.345...
#   [0.5, 0.33088235294117646, 0.3676470588235294,...
#   [0.5024509803921569, 0.34068627450980393, 0.37...
#
#                                      test_epoch_acc  \
#   [0.45588235294117646, 0.2622549019607843, 0.27...
#   [0.4632352941176471, 0.25980392156862747, 0.28...
#   [0.4852941176470588, 0.2622549019607843, 0.281...
#   [0.49019607843137253, 0.2622549019607843, 0.29...
#   [0.47058823529411764, 0.25245098039215685, 0.2...
#   [0.4681372549019608, 0.25245098039215685, 0.27...
#   [0.5, 0.26715686274509803, 0.3014705882352941,...
#   [0.5049019607843137, 0.2769607843137255, 0.333...
#
#                                     test_epoch_loss
#   [1.8380921097362743, 1.7750173386405497, 1.703...
#   [1.8361124711878158, 1.7731742858886719, 1.701...
#   [1.82219318782582, 1.7552856277017033, 1.70425...
#   [1.8201917269650627, 1.750795420478372, 1.7103...
#   [1.8301161527633667, 1.767697530634263, 1.7057...
#   [1.8278653551550472, 1.7644856396843405, 1.707...
#   [1.8140373229980469, 1.7479664437911089, 1.716...
#   [1.8113201155382044, 1.7434505294351017, 1.708...

# %%
list(GridSrach['hyper_param'])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/jr/h5q7lybd23l1htckxf1x0dnr0000gn/T/ipykernel_6259/2414827280.py in <cell line: 1>()
# ----> 1 list(GridSrach['hyper_param']).str()
#
# AttributeError: 'list' object has no attribute 'str'
